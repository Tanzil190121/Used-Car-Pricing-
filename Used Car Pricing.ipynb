# %%
import pandas as pd

# %%
df=pd.read_csv('autos.csv')

# %%
df
# Out:
#          index          dateCrawled  \
# 0            0  2016-03-24 11:52:17
# 1            1  2016-03-24 10:58:45
# 2            2  2016-03-14 12:52:21
# 3            3  2016-03-17 16:54:04
# 4            4  2016-03-31 17:25:20
# ...        ...                  ...
# 371523  371523  2016-03-14 17:48:27
# 371524  371524  2016-03-05 19:56:21
# 371525  371525  2016-03-19 18:57:12
# 371526  371526  2016-03-20 19:41:08
# 371527  371527  2016-03-07 19:39:19
#
#                                                 name  seller offerType  price  \
# 0                                         Golf_3_1.6  privat   Angebot    480
# 1                               A5_Sportback_2.7_Tdi  privat   Angebot  18300
# 2                     Jeep_Grand_Cherokee_"Overland"  privat   Angebot   9800
# 3                                 GOLF_4_1_4__3TÜRER  privat   Angebot   1500
# 4                     Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot   3600
# ...

# %%
df=df.dropna()

# %%
df
# Out:
#          index          dateCrawled  \
# 3            3  2016-03-17 16:54:04
# 4            4  2016-03-31 17:25:20
# 5            5  2016-04-04 17:36:23
# 6            6  2016-04-01 20:48:51
# 7            7  2016-03-21 18:54:38
# ...        ...                  ...
# 371520  371520  2016-03-19 19:53:49
# 371521  371521  2016-03-27 20:36:20
# 371524  371524  2016-03-05 19:56:21
# 371525  371525  2016-03-19 18:57:12
# 371527  371527  2016-03-07 19:39:19
#
#                                                      name  seller offerType  \
# 3                                      GOLF_4_1_4__3TÜRER  privat   Angebot
# 4                          Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot
# 5       BMW_316i___e36_Limousine___Bastlerfahrzeug__Ex...  privat   Angebot
# 6                             Peugeot_206_CC_110_Platinum  privat   Angebot
# 7                            VW_Derby_Bj_80__Scheunenfund  privat   Angebot
# ...

# %%
df.isnull().sum()
# Out:
# index                  0
# dateCrawled            0
# name                   0
# seller                 0
# offerType              0
# price                  0
# abtest                 0
# vehicleType            0
# yearOfRegistration     0
# gearbox                0
# powerPS                0
# model                  0
# kilometer              0
# monthOfRegistration    0
# fuelType               0
# brand                  0
# notRepairedDamage      0
# dateCreated            0
# nrOfPictures           0
# postalCode             0
# lastSeen               0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
first=LabelEncoder()

# %%
df['name']=first.fit_transform(df['name'])
df['vehicleType']=first.fit_transform(df['vehicleType'])
df['gearbox']=first.fit_transform(df['gearbox'])
df['model']=first.fit_transform(df['model'])
df['fuelType']=first.fit_transform(df['fuelType'])
df['brand']=first.fit_transform(df['brand'])
df['abtest']=first.fit_transform(df['abtest'])
df['yearOfRegistration']=first.fit_transform(df['yearOfRegistration'])
df['notRepairedDamage']=first.fit_transform(df['notRepairedDamage'])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14324\3586388554.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['name']=first.fit_transform(df['name'])
# C:\Users\user\AppData\Local\Temp\ipykernel_14324\3586388554.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['vehicleType']=first.fit_transform(df['vehicleType'])
# C:\Users\user\AppData\Local\Temp\ipykernel_14324\3586388554.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df
# Out:
#          index          dateCrawled    name  seller offerType  price  abtest  \
# 3            3  2016-03-17 16:54:04   49852  privat   Angebot   1500       1
# 4            4  2016-03-31 17:25:20  110371  privat   Angebot   3600       1
# 5            5  2016-04-04 17:36:23   17693  privat   Angebot    650       1
# 6            6  2016-04-01 20:48:51   94170  privat   Angebot   2200       1
# 7            7  2016-03-21 18:54:38  120738  privat   Angebot      0       1
# ...        ...                  ...     ...     ...       ...    ...     ...
# 371520  371520  2016-03-19 19:53:49  149773  privat   Angebot   3200       0
# 371521  371521  2016-03-27 20:36:20   90905  privat   Angebot   1150       0
# 371524  371524  2016-03-05 19:56:21  114031  privat   Angebot   1199       1
# 371525  371525  2016-03-19 18:57:12  137394  privat   Angebot   9200       1
# 371527  371527  2016-03-07 19:39:19   27191  privat   Angebot  28990       0
#
# ...

# %%
x=df.iloc[:,5:-4]
y=df.iloc[:,5]

# %%
x
# Out:
#         price  abtest  vehicleType  yearOfRegistration  gearbox  powerPS  \
# 3        1500       1            4                  71        1       75
# 4        3600       1            4                  78        1       69
# 5         650       1            6                  65        1      102
# 6        2200       1            2                  74        1      109
# 7           0       1            6                  50        1       50
# ...       ...     ...          ...                 ...      ...      ...
# 371520   3200       0            6                  74        1      225
# 371521   1150       0            1                  70        1        0
# 371524   1199       1            2                  70        0      101
# 371525   9200       1            1                  66        1      102
# 371527  28990       0            6                  83        1      320
#
#         model  kilometer  monthOfRegistration  fuelType  brand  \
# ...

# %%
y
# Out:
# 3          1500
# 4          3600
# 5           650
# 6          2200
# 7             0
#           ...
# 371520     3200
# 371521     1150
# 371524     1199
# 371525     9200
# 371527    28990
# Name: price, Length: 260956, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.4)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression()

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
reg.predict(x_test)
# Out:
# array([1200., 2200., 1800., ..., 2100.,  680., 1490.])

# %%
reg.score(x_test,y_test)
# Out:
# 1.0

# %%
y_test
# Out:
# 307598     1200
# 134386     2200
# 273112     1800
# 38656      3699
# 210660    11450
#           ...
# 239531     8550
# 91113      1999
# 165425     2100
# 39097       680
# 38695      1490
# Name: price, Length: 104383, dtype: int64
